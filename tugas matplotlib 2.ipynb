# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data_jualan = pd.read_excel("data_penjualan-Copy.xlsx")
data_jualan
# Out:
#          Tanggal      Jenis Produk  Jumlah Order   Harga      Total
# 0     05/08/2022        Foodpak260        1000.0  1800.0  1800000.0
# 1     05/08/2022   FoodpakMatte245        1000.0  1900.0  1900000.0
# 2     05/08/2022  CraftLaminasi290        5000.0   750.0  3750000.0
# 3     05/08/2022  CraftLaminasi290        1000.0  1200.0  1200000.0
# 4     07/08/2022        Dupleks310        1000.0  1550.0  1550000.0
# ...          ...               ...           ...     ...        ...
# 1071  14/11/2023          Ivory230        1000.0   900.0   900000.0
# 1072  15/11/2023  CraftLaminasi290        2000.0   800.0  1600000.0
# 1073  15/11/2023  CraftLaminasi290        1500.0   875.0  1312500.0
# 1074  15/11/2023      FoodpakMatte        1000.0  2200.0  2200000.0
# 1075  15/11/2023       GreaseProof        1000.0   300.0   300000.0
#
# [1076 rows x 5 columns]

# %%
data_craft = data_jualan[data_jualan['Jenis Produk'] == 'CraftLaminasi290']
data_craft["Tanggal"] = pd.to_datetime(data_craft["Tanggal"], format="%d/%m/%Y")
data_craft["Bulan"] = data_craft["Tanggal"].dt.month_name()
data_craft
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24328\3936933741.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_craft["Tanggal"] = pd.to_datetime(data_craft["Tanggal"], format="%d/%m/%Y")
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24328\3936933741.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_craft["Bulan"] = data_craft["Tanggal"].dt.month_name()
#         Tanggal      Jenis Produk  Jumlah Order   Harga      Total     Bulan
# ...

# %%
data_craft_2022 = data_craft[data_craft["Tanggal"].dt.year==2022]
data_craft_2022
# Out:
#        Tanggal      Jenis Produk  Jumlah Order   Harga      Total      Bulan
# 2   2022-08-05  CraftLaminasi290        5000.0   750.0  3750000.0     August
# 3   2022-08-05  CraftLaminasi290        1000.0  1200.0  1200000.0     August
# 13  2022-08-11  CraftLaminasi290        1000.0     NaN   850000.0     August
# 20  2022-08-12  CraftLaminasi290        3000.0     NaN  2400000.0     August
# 21  2022-08-12  CraftLaminasi290         500.0   600.0   300000.0     August
# 61  2022-09-03  CraftLaminasi290        6000.0   950.0  5700000.0  September
# 63  2022-09-05  CraftLaminasi290        1000.0  1100.0  1100000.0  September
# 69  2022-09-08  CraftLaminasi290        5000.0   850.0  4250000.0  September
# 77  2022-09-14  CraftLaminasi290        2000.0  1950.0  3900000.0  September
# 79  2022-09-14  CraftLaminasi290           NaN  1200.0  1200000.0  September
# 89  2022-09-19  CraftLaminasi290        5000.0  1200.0  6000000.0  September
# ...

# %%
penjualan_bulanan_craft_2022 = data_craft_2022.groupby("Bulan").agg(
    jumlah_penjualan_craft_2022=('Jumlah Order', "sum"),
    total_pendapatan_craft_2022 =("Total", "sum")).reindex(["January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"])
penjualan_bulanan_craft_2022
# Out:
#            jumlah_penjualan_craft_2022  total_pendapatan_craft_2022
# Bulan
# January                            NaN                          NaN
# February                           NaN                          NaN
# March                              NaN                          NaN
# April                              NaN                          NaN
# May                                NaN                          NaN
# June                               NaN                          NaN
# July                               NaN                          NaN
# August                         10500.0                    8500000.0
# September                      33000.0                   41950000.0
# October                        22500.0                   28050000.0
# November                       21000.0                   27750000.0
# December                       21000.0                   24625000.0

# %%
plt.figure(figsize=(10,5))
plt.bar(penjualan_bulanan_craft_2022.index, penjualan_bulanan_craft_2022["jumlah_penjualan_craft_2022"], label="Jumlah Penjualan", color="skyblue")
plt.title("Jumlah Penjualan CraftLaminasi290 Setiap Bulan Tahun 2022")
plt.xlabel("Bulan")
plt.ylabel("Jumlah Order")
plt.xticks(rotation=50)
plt.legend()
plt.show()

# %%
data_craft_2023 = data_craft.copy()
data_craft_2023 = data_craft[data_craft["Tanggal"].dt.year==2023]
data_craft_2023
# Out:
#         Tanggal      Jenis Produk  Jumlah Order   Harga      Total     Bulan
# 325  2023-01-06  CraftLaminasi290        4000.0  1600.0  6400000.0   January
# 333  2023-01-06  CraftLaminasi290        5000.0   850.0  4250000.0   January
# 336  2023-01-06  CraftLaminasi290        1000.0  4500.0  4500000.0   January
# 337  2023-01-06  CraftLaminasi290        1000.0  1300.0  1300000.0   January
# 338  2023-01-06  CraftLaminasi290        1000.0  3050.0  3050000.0   January
# ...         ...               ...           ...     ...        ...       ...
# 1022 2023-10-28  CraftLaminasi290        1000.0   875.0   875000.0   October
# 1023 2023-10-28  CraftLaminasi290        1000.0   850.0   850000.0   October
# 1053 2023-11-09  CraftLaminasi290        2000.0  1600.0  3200000.0  November
# 1072 2023-11-15  CraftLaminasi290        2000.0   800.0  1600000.0  November
# 1073 2023-11-15  CraftLaminasi290        1500.0   875.0  1312500.0  November
#
# [74 rows x 6 columns]

# %%
penjualan_bulanan_craft_2023 = data_craft_2023.groupby("Bulan").agg(
    jumlah_penjualan_craft_2023=('Jumlah Order', "sum"),
    total_pendapatan_craft_2023 =("Total", "sum")).reindex(["January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"])
penjualan_bulanan_craft_2023
# Out:
#            jumlah_penjualan_craft_2023  total_pendapatan_craft_2023
# Bulan
# January                        22500.0                   28875000.0
# February                       20000.0                   17800000.0
# March                          16000.0                   19450000.0
# April                          21000.0                   21200000.0
# May                             9000.0                   10200000.0
# June                           12000.0                   13025000.0
# July                           13000.0                   14400000.0
# August                         24500.0                   24387500.0
# September                      11000.0                   13012500.0
# October                        17000.0                   17837500.0
# November                        5500.0                    6112500.0
# December                           NaN                          NaN

# %%
plt.figure(figsize=(10,5))
plt.bar(penjualan_bulanan_craft_2023.index, penjualan_bulanan_craft_2023["jumlah_penjualan_craft_2023"], label="Jumlah Penjualan", color="mediumseagreen")
plt.title("Jumlah Penjualan CraftLaminasi290 Setiap Bulan Tahun 2023")
plt.xlabel("Bulan")
plt.ylabel("Jumlah Order")
plt.xticks(rotation=50)
plt.legend()
plt.show()

# %%
data_HVS = data_jualan.copy()
data_HVS = data_jualan[data_jualan['Jenis Produk'] == 'HVS']
data_HVS["Tanggal"] = pd.to_datetime(data_HVS["Tanggal"], format="%d/%m/%Y")
data_HVS["Bulan"] = data_HVS["Tanggal"].dt.month_name()
data_HVS
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24328\4189149316.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_HVS["Tanggal"] = pd.to_datetime(data_HVS["Tanggal"], format="%d/%m/%Y")
# C:\Users\Asus\AppData\Local\Temp\ipykernel_24328\4189149316.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_HVS["Bulan"] = data_HVS["Tanggal"].dt.month_name()
#         Tanggal Jenis Produk  Jumlah Order  Harga       Total      Bulan
# ...

# %%
data_HVS_2022 = data_HVS.copy()
data_HVS_2022 = data_HVS[data_HVS["Tanggal"].dt.year==2022]
data_HVS_2022
# Out:
#        Tanggal Jenis Produk  Jumlah Order  Harga      Total      Bulan
# 8   2022-08-09          HVS        1500.0    NaN  1275000.0     August
# 62  2022-09-03          HVS       20000.0  250.0  5000000.0  September
# 128 2022-10-07          HVS       20000.0  250.0  5000000.0    October
# 197 2022-11-20          HVS       20000.0  250.0  5000000.0   November
# 256 2022-12-07          HVS       20000.0  250.0  5000000.0   December

# %%
penjualan_bulanan_HVS_2022 = data_HVS_2022.groupby("Bulan").agg(
    jumlah_penjualan_HVS_2022=('Jumlah Order', "sum"),
    total_pendapatan_HVS_2022 =("Total", "sum")).reindex(["January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"])
penjualan_bulanan_HVS_2022
# Out:
#            jumlah_penjualan_HVS_2022  total_pendapatan_HVS_2022
# Bulan
# January                          NaN                        NaN
# February                         NaN                        NaN
# March                            NaN                        NaN
# April                            NaN                        NaN
# May                              NaN                        NaN
# June                             NaN                        NaN
# July                             NaN                        NaN
# August                        1500.0                  1275000.0
# September                    20000.0                  5000000.0
# October                      20000.0                  5000000.0
# November                     20000.0                  5000000.0
# December                     20000.0                  5000000.0

# %%
plt.figure(figsize=(10,5))
plt.bar(penjualan_bulanan_HVS_2022.index, penjualan_bulanan_HVS_2022["jumlah_penjualan_HVS_2022"], label="Jumlah Penjualan", color="red")
plt.title("Jumlah Penjualan HVS Setiap Bulan Tahun 2022")
plt.xlabel("Bulan")
plt.ylabel("Jumlah Order")
plt.xticks(rotation=50)
plt.legend()
plt.show()

# %%
data_HVS_2023 = data_HVS.copy()
data_HVS_2023 = data_HVS[data_HVS["Tanggal"].dt.year==2023]
data_HVS_2023
# Out:
#         Tanggal Jenis Produk  Jumlah Order  Harga       Total     Bulan
# 345  2023-01-06          HVS       20000.0  250.0   5000000.0   January
# 431  2023-02-21          HVS       40000.0  250.0  10000000.0  February
# 547  2023-04-29          HVS       20000.0  250.0   5000000.0     April
# 570  2023-05-05          HVS        2000.0  250.0         NaN       May
# 684  2023-06-26          HVS       20000.0  250.0   5000000.0      June
# 836  2023-08-20          HVS        5000.0  300.0   1500000.0    August
# 850  2023-08-24          HVS       20000.0  250.0   5000000.0    August
# 968  2023-10-08          HVS       10000.0  275.0   2750000.0   October
# 1001 2023-10-20          HVS       20000.0  250.0   5000000.0   October

# %%
penjualan_bulanan_HVS_2023 = data_HVS_2023.groupby("Bulan").agg(
    jumlah_penjualan_HVS_2023=('Jumlah Order', "sum"),
    total_pendapatan_HVS_2023 =("Total", "sum")).reindex(["January", "February", "March", "April", "May", "June",
    "July", "August", "September", "October", "November", "December"])
penjualan_bulanan_HVS_2023
# Out:
#            jumlah_penjualan_HVS_2023  total_pendapatan_HVS_2023
# Bulan
# January                      20000.0                  5000000.0
# February                     40000.0                 10000000.0
# March                            NaN                        NaN
# April                        20000.0                  5000000.0
# May                           2000.0                        0.0
# June                         20000.0                  5000000.0
# July                             NaN                        NaN
# August                       25000.0                  6500000.0
# September                        NaN                        NaN
# October                      30000.0                  7750000.0
# November                         NaN                        NaN
# December                         NaN                        NaN

# %%
plt.figure(figsize=(10,5))
plt.bar(penjualan_bulanan_HVS_2023.index, penjualan_bulanan_HVS_2023["jumlah_penjualan_HVS_2023"], label="Jumlah Penjualan", color="orange")
plt.title("Jumlah Penjualan HVS Setiap Bulan Tahun 2023")
plt.xlabel("Bulan")
plt.ylabel("Jumlah Order")
plt.xticks(rotation=50)
plt.legend()
plt.show()

# %%
#gabungan data CraftLaminasi290 dan HVS tahun 2022 dan 2023
plt.figure(figsize=(15,7))
plt.plot(penjualan_bulanan_craft_2022.index, penjualan_bulanan_craft_2022["jumlah_penjualan_craft_2022"], label="Jumlah Penjualan CraftLaminasi290 2022", color="skyblue")
plt.plot(penjualan_bulanan_craft_2023.index, penjualan_bulanan_craft_2023["jumlah_penjualan_craft_2023"], label="Jumlah Penjualan CraftLaminasi290 2023", color="mediumseagreen")
plt.plot(penjualan_bulanan_HVS_2022.index, penjualan_bulanan_HVS_2022["jumlah_penjualan_HVS_2022"], label="Jumlah Penjualan HVS 2022", color="red")
plt.plot(penjualan_bulanan_HVS_2023.index, penjualan_bulanan_HVS_2023["jumlah_penjualan_HVS_2023"], label="Jumlah Penjualan HVS 2023", color="orange")
plt.title("Jumlah Penjualan CraftLaminasi290 dan HVS Setiap Bulan Tahun 2022 dan 2023")
plt.xlabel("Bulan")
plt.ylabel("Jumlah Order")
plt.xticks(rotation=50)
plt.legend()

# %% [markdown]
# 1. Produk yang Lebih Unggul
# Produk CraftLaminasi290 memiliki jumlah penjualan yang lebih tinggi dibandingkan HVS di sebagian besar bulan.
# Ini terlihat dari garis grafik yang lebih tinggi untuk CraftLaminasi290 dibandingkan HVS.
# 2. Bulan-Bulan Penurunan Penjualan
# CraftLaminasi290 2022: Mengalami penurunan setelah Agustus.
# CraftLaminasi290 2023: Penurunan terlihat dari Januari ke Mei dan kemudian dari September ke Desember.
# HVS 2022: Tidak banyak perubahan setelah September, cenderung stabil.
# HVS 2023: Penurunan signifikan terjadi dari April ke Mei.
# 3. Peningkatan Tertinggi dan Terendah
# Peningkatan Tertinggi:
# CraftLaminasi290 2022: Dari Juli ke Agustus.
# CraftLaminasi290 2023: Dari Juli ke Agustus.
# HVS 2023: Dari Mei ke Juni (setelah penurunan drastis).
# Peningkatan Terendah (Penurunan Tertinggi):
# CraftLaminasi290 2023: Dari April ke Mei.
# HVS 2023: Dari April ke Mei (turun hingga hampir nol).
# Kesimpulannya, CraftLaminasi290 lebih unggul dibandingkan HVS, terutama pada tahun 2022 dan pertengahan 2023. Namun, HVS juga mengalami lonjakan signifikan di pertengahan 2023.
